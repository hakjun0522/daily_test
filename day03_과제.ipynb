# %%
#Q1. 1부터 5까지의 숫자를 대각선에 갖는 대각행렬을 만드세요.
np.diag(np.arange(5)+1)

# %%
#Q2. 2부터 10까지의 짝수를 대각선에 갖는 대각행렬을 만드세요
np.diag((np.arange(5)+1)*2)

# %%
#Q3. 1붵 10까지의 숫자를 대각선에 갖는 대각행렬을 만들고, 그 대각행렬을 전치행렬로 바꾸세요.

a = np.diag(np.arange(10)+1)
print(a,'\n')
b = a.transpose()
print(b)

# %%
#Q 1부터 10까지의 숫자를 대각선에 갖는 대각행렬을 만들고, 그 대각행렬의 역행렬을 구하세요.
a=np.diag(np.arange(5)+1)
print(a)
b = np.linalg.inv(a)
print(b)

# %%
#Q 1부터 10까지 숫자를 대각선에 갖는 대각행렬을 만들고 , 그 대각행렬을 제곱하세요
a=np.diag(np.arange(10)+1)
result = a@a
print(result)

# %% [markdown]
# #Q 1부터 10까지 숫자를 대각선에 갖는 대각행렬을 만들고 , 그 대각행렬을 제곱하세요
# a=np.diag(np.arange(10)+1)
# result = a@a
# print(result)

# %%
import matplotlib.pyplot as plt

# NDate 별 스택된 막대그래프
plt.figure(figsize=(12, 6))
df1[['Close']].plot(kind='bar', stacked=True, color=['skyblue'])
plt.title('Stacked Bar Chart of Close, Start, High, Low Prices by NDate')
plt.xlabel('NDate')
plt.ylabel('Price')
plt.show()

# 6월만을 추출하여 Close 칼럼으로 일별 막대 그래프
df1_june = df1[df1.index.month == 6]
plt.figure(figsize=(12, 6))
df1_june['Close'].plot(kind='bar', color='green')
plt.title('Bar Chart of Close Prices in June')
plt.xlabel('NDate')
plt.ylabel('Close Price')
plt.show()

# 히스토그램
plt.figure(figsize=(10, 6))
plt.hist(df1['Close'], bins=10, color='orange', edgecolor='black')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.title('Histogram of Close Prices')
plt.show()

# %% [markdown]
# df에서 Volume 칼럼으로 히스토그램를 표현하세요.

# %%
import matplotlib.pyplot as plt

# 히스토그램
plt.figure(figsize=(10, 6))
plt.hist(df['Volume'], bins=range(0, df['Volume'].max()+100000, 100000), color='blue', edgecolor='black')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.title('Histogram of Volume')
plt.show()

# %% [markdown]
# Q3_0115 df Close 칼럼과 Volume 칼럼으로 산점도를 표현하세요.

# %%
import matplotlib.pyplot as plt

# 산점도
plt.figure(figsize=(10, 6))
plt.scatter(df['Close'], df['Volume'], color='blue', alpha=0.5)
plt.xlabel('Close Price')
plt.ylabel('Volume')
plt.title('Scatter Plot of Close Price and Volume')
plt.show()

# %% [markdown]
# 04_0115.df1 Close 칼럼의 BoxPlot을 표현하세요

# %%
import matplotlib.pyplot as plt

# Close 칼럼에 대한 BoxPlot
plt.figure(figsize=(8, 6))
df1['Close'].plot(kind='box', vert=False, notch=True, patch_artist=True, color='skyblue')
plt.title('BoxPlot of Close Prices')
plt.xlabel('Close Price')
plt.show()
